# %%
import pandas as pd

# %%
imu_df = pd.read_csv('imu.csv', low_memory=False)

# %%
imu_df.head()
# Out:
#       timestamp    gyro_x    gyro_y    gyro_z  acc_x  acc_y     acc_z
# 0  1.669243e+09 -0.017890 -0.010996 -0.004625    NaN    NaN       NaN  \
# 1  1.669243e+09 -0.018500 -0.010123 -0.003491  1.810 -0.018  9.662001
# 2  1.669243e+09 -0.018675 -0.013003 -0.003491  1.782  0.128  9.912001
# 3  1.669243e+09 -0.017191 -0.009948 -0.004625  1.712  0.032  9.932000
# 4  1.669243e+09 -0.020944 -0.012130 -0.005062  1.648  0.238  9.870001
#
#    conf_gyro  conf_acc
# 0        NaN       NaN
# 1   0.993786  0.971457
# 2   0.986406  0.945539
# 3   0.984853  0.976050
# 4   0.971647  0.986877

# %%
dbw_df = pd.read_csv('dbw.csv', low_memory=False)

# %%
dbw_df.head()
# Out:
#       timestamp  speed  yaw_rate  v_front_left  v_front_right  v_rear_left
# 0  1.669243e+09   8.83    -0.008          8.90           8.91         8.87  \
# 1  1.669243e+09   8.92    -0.008          9.01           9.01         8.86
# 2  1.669243e+09   8.92    -0.008          9.00           9.01         8.97
# 3  1.669243e+09   8.96    -0.008          9.08           9.08         9.00
# 4  1.669243e+09   9.02    -0.008          9.21           9.18         9.06
#
#    v_rear_right
# 0          8.87
# 1          8.91
# 2          8.98
# 3          9.06
# 4          9.06

# %%
dbw_df['timestamp'].plot.line()
# Out:
# <Axes: >

# %%
imu_df['timestamp'].plot.line()
# Out:
# <Axes: >

# %%
imu_df[['conf_gyro', 'gyro_x', 'gyro_y', 'gyro_z']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
imu_df[['conf_acc', 'acc_x', 'acc_y', 'acc_z']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
dbw_df['yaw_rate'].plot.line()
# Out:
# <Axes: >

# %%
imu_df.describe()
# Out:
#           timestamp       gyro_x       gyro_y       gyro_z        acc_x
# count  2.728000e+03  2726.000000  2726.000000  2725.000000  2720.000000  \
# mean   1.669243e+09     0.000311    -0.003527     0.044644     0.490906
# std    8.747339e+00     0.031568     0.030466     0.049372     0.849343
# min    1.669243e+09    -0.124235    -0.105937    -0.144267    -2.803122
# 25%    1.669243e+09    -0.017955    -0.021785     0.002094    -0.222000
# 50%    1.669243e+09     0.002007    -0.005411     0.037948     0.639000
# 75%    1.669243e+09     0.019460     0.013439     0.091630     1.167000
# max    1.669243e+09     0.177166     0.137729     0.147659     3.576616
#
#              acc_y        acc_z    conf_gyro     conf_acc
# count  2720.000000  2720.000000  2720.000000  2720.000000
# mean      0.294505     9.789492     0.946297     0.918074
# std       0.795762     0.727396     0.112899     0.109665
# min      -3.298521     5.910000     0.000000     0.000000
# ...

# %%
dbw_df.describe()
# Out:
#           timestamp       speed     yaw_rate  v_front_left  v_front_right
# count  7.360000e+02  736.000000  1111.000000    736.000000     736.000000  \
# mean   1.669243e+09   20.835802     0.034536     21.007228      21.069620
# std    8.582744e+00    2.850802     0.030704      2.848728       2.881424
# min    1.669243e+09    8.830000    -0.016000      8.900000       8.910000
# 25%    1.669243e+09   20.972500     0.000000     21.162500      21.227500
# 50%    1.669243e+09   21.850000     0.050000     22.010000      22.100000
# 75%    1.669243e+09   22.450000     0.050000     22.652500      22.680000
# max    1.669243e+09   22.930000     0.093000     23.030000      23.230000
#
#        v_rear_left  v_rear_right
# count   736.000000    736.000000
# mean     20.947065     21.030245
# std       2.885757      2.920814
# min       8.860000      8.870000
# 25%      21.000000     21.132500
# 50%      21.945000     22.060000
# 75%      22.650000     22.700000
# ...
